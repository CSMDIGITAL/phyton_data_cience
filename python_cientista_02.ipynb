# %% [markdown]
# ## Exercício - Estatística Descritiva (medida de tendência central)

# %% [markdown]
# Um pesquisador ficou em determinado cruzamento durante 18 dias. Nesse cruzamento movimentado em mediu o nível de ruído (em decibéis).

# %% [markdown]
# MEDIA

# %%
# carregar o dataset 
# calcular a media
# df.Campo.mean()

# %% [markdown]
# ## Representação da Média

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# importe o pandas

# %%
import pandas as pd

# %%
# carregue o dataset_ruido.csv
df = pd.read_csv('datasets/dataset_ruido.csv')

# %%
import pandas as pd

# %%
df = pd.read_csv('datasets/dataset_ruido.csv')

# %%
print(df.columns.tolist())
# Out:
# ['numero_do_dia;nivel_ruido (dB)']

# %%
df = pd.read_csv('datasets/dataset_ruido.csv', sep=';', decimal=',')

# %%
df.mean()
# Out:
# numero_do_dia         9.500000
# nivel_ruido (dB)    108.444444
# dtype: float64

# %%
# agora calcule a moda
df = pd.read_csv('datasets/dataset_ruido.csv', sep=';', decimal=',')

# %%
# média, mediana, moda da coluna com nome original
media  = df['nivel_ruido (dB)'].mean()
mediana = df['nivel_ruido (dB)'].median()
moda   = df['nivel_ruido (dB)'].mode()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   numero_do_dia     18 non-null     int64
#  1   nivel_ruido (dB)  18 non-null     int64
# dtypes: int64(2)
# memory usage: 420.0 bytes

# %%
print(df.shape)       # linhas, colunas
print(df.columns)     # nomes das colunas
df.info()             # tipos e nulos
df.head(3)            # primeiras linhas
df.describe()         # estatísticas numéricas
# Out:
# (18, 2)
# Index(['numero_do_dia', 'nivel_ruido (dB)'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   numero_do_dia     18 non-null     int64
#  1   nivel_ruido (dB)  18 non-null     int64
# dtypes: int64(2)
# memory usage: 420.0 bytes
#        numero_do_dia  nivel_ruido (dB)
# count      18.000000         18.000000
# mean        9.500000        108.444444
# std         5.338539         12.093860
# min         1.000000         85.000000
# 25%         5.250000         99.500000
# 50%         9.500000        108.500000
# 75%        13.750000        119.250000
# max        18.000000        127.000000

# %%
resumo = {
    "média": media,
    "mediana": mediana,
    "moda": moda.iloc[0] if not moda.empty else None
}
resumo
# Out:
# {'média': np.float64(108.44444444444444),
#  'mediana': np.float64(108.5),
#  'moda': np.int64(120)}

# %% [markdown]
# ## Mediana

# %% [markdown]
# Tecnico
# Explicar para publico leigo
# Primeiro os dados tem que estar em oderm crescente
# Tamanho da amostra e par ou impar

# %%
# ordene a calcule a mediana agora
# ordenar e calcular a mediana sem renomear
df_ordenado = df.sort_values(by='nivel_ruido (dB)')
mediana = df_ordenado['nivel_ruido (dB)'].median()
mediana
# Out:
# np.float64(108.5)

# %%
df = df.rename(columns={"nivel_ruido (dB)": "nivel_ruido_db"})

# %%
print(df.columns.tolist())
# Out:
# ['numero_do_dia', 'nivel_ruido_db']

# %%
df_ordenado = df.sort_values(by="nivel_ruido_db")

# %%
df.nivel_ruido_db.median()
# Out:
# np.float64(108.5)

# %% [markdown]
# par (n=18)
# a mediana e cauculada fazend-se uma media dos valores que se encotram:
# n/2 = 9 elemento e (n+2)/2=10 elemento

# %%
# ordene e calcule a mediana
df_ordenado = df.sort_values(by='nivel_ruido_db')

# %%
df_ordenado
# Out:
#     numero_do_dia  nivel_ruido_db
# 0               1              85
# 1               2              92
# 2               3              95
# 3               4              98
# 4               5              99
# 5               6             101
# 6               7             103
# 7               8             105
# 8               9             107
# 9              10             110
# 10             11             112
# 11             12             114
# 12             13             117
# 13             14             120
# 14             15             120
# 15             16             122
# 16             17             125
# 17             18             127

# %%
Interpretacao: "em metade dos dias analisados o nivel de ruido 
Foi inferior ou igual a 108,5 decibeis"

# %% [markdown]
# ## Moda

# %%
# agora calcule a moda
df.nivel_ruido_db.mode()
# Out:
# 0    120
# Name: nivel_ruido_db, dtype: int64

# %% [markdown]
# - Na  frequencia
# - A moda vai no auxiliar nos desafios aonde precisaremos calcular a frequencia

# %%
df.head()
# Out:
#    numero_do_dia  nivel_ruido_db
# 0              1              85
# 1              2              92
# 2              3              95
# 3              4              98
# 4              5              99

# %%
df.describe()
# Out:
#        numero_do_dia  nivel_ruido_db
# count      18.000000       18.000000
# mean        9.500000      108.444444
# std         5.338539       12.093860
# min         1.000000       85.000000
# 25%         5.250000       99.500000
# 50%         9.500000      108.500000
# 75%        13.750000      119.250000
# max        18.000000      127.000000

# %%
df.nivel_ruido_db
# Out:
# 0      85
# 1      92
# 2      95
# 3      98
# 4      99
# 5     101
# 6     103
# 7     105
# 8     107
# 9     110
# 10    112
# 11    114
# 12    117
# 13    120
# 14    120
# 15    122
# 16    125
# 17    127
# Name: nivel_ruido_db, dtype: int64

# %%
df["nivel_ruido_db"][0:5]
# Out:
# 0    85
# 1    92
# 2    95
# 3    98
# 4    99
# Name: nivel_ruido_db, dtype: int64

# %%
df["nivel_ruido_db"][8:14]
# Out:
# 8     107
# 9     110
# 10    112
# 11    114
# 12    117
# 13    120
# Name: nivel_ruido_db, dtype: int64

# %% [markdown]
# ## Quero o nivel  de ruido no 10 elemnto

# %%
df.head(11)
# Out:
#     numero_do_dia  nivel_ruido_db
# 0               1              85
# 1               2              92
# 2               3              95
# 3               4              98
# 4               5              99
# 5               6             101
# 6               7             103
# 7               8             105
# 8               9             107
# 9              10             110
# 10             11             112

# %%
df.loc[10]
# Out:
# numero_do_dia      11
# nivel_ruido_db    112
# Name: 10, dtype: int64

# %%
df.loc[df.nivel_ruido_db >=117]
# Out:
#     numero_do_dia  nivel_ruido_db
# 12             13             117
# 13             14             120
# 14             15             120
# 15             16             122
# 16             17             125
# 17             18             127
